# %% [markdown]
# ### Найтим максимальное число

# %%
def max_number(numbers):
    result = None
### WRITE SOLUTION HERE
    result = max(numbers)
    return result

# %%
maximum = max_number([3, 7, 2])
print(f"Max = {maximum}")
# Out:
# Max = 7

# %%
# Tests 15 points.
assert max_number([10, 20, 30]) == 30
assert max_number([-1, -5, -3]) == -1
